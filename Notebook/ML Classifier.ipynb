# %%
# !pip install openpyxl --upgrade

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data = pd.read_csv('/content/drive/MyDrive/Data/Data modified/try_final.xlsx')
data = pd.read_excel('/content/drive/MyDrive/Data/Data modified/LAST.xlsx')

# %%
data.columns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
#for loading and visualizing audio files
import librosa
import librosa.display
import tensorflow as tf
from tensorflow import keras
#to play audio
import IPython.display as ipd

import pickle
from tensorflow.keras.utils import to_categorical

from keras.models import Sequential
from keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import sys
import tqdm
import seaborn as sns
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from IPython.display import Image
from sklearn.model_selection import learning_curve
from sklearn.svm import SVC
from xgboost import XGBClassifier

from sklearn import metrics
from sklearn.metrics import f1_score,recall_score,precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition,tree
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2)

# %%
train.columns

# %% [markdown]
# # ***PREDICT I1***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7','I8', 'I9'])
y_train = train['I1']
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade','I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'])
y_test = test['I1']

# %%
y_train.unique()
# Out:
# array([4, 5, 0, 3, 2, 1])

# %% [markdown]
# ***DESCISION TREE***

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=['1', '2', '3','4','5','0']))

# %% [markdown]
# ***SVM***

# %%
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['1', '2', '3','4','5','0']))

# %% [markdown]
# ***NB***

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['1', '2', '3','4','5','0']))

# %%
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 5, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['1', '2', '3','4','5','0']))

# %%
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['1', '2', '3','4','5','0']))

# %% [markdown]
# # ***PREDICT I2***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I3', 'I4', 'I5', 'I6', 'I7','I8', 'I9'])
y_train = train['I2']
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'])
y_test = test['I2']

print(y_train.unique())
print(y_test.unique())

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=[ '8',  '9',  '7', '10',  '6']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['8',  '9',  '7', '10',  '6']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['8',  '9',  '7', '10',  '6']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['8',  '9',  '7', '10',  '6']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['8',  '9',  '7', '10',  '6']))

# %% [markdown]
# # ***PREDICT I3***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I4', 'I5', 'I6', 'I7','I8', 'I9'])
y_train = train['I3']
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9'])
y_test = test['I3']

print(y_train.unique())
print(y_test.unique())

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=[ '8',  '9',  '7', '10','4']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['8',  '9',  '7', '10','4']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['8',  '9',  '7', '10','4']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['8',  '9',  '7', '10', '0','4']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['8',  '9',  '7', '10', '4']))

# %% [markdown]
# # ***PREDICT I4***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I5', 'I6', 'I7','I8', 'I9'])
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I5', 'I6', 'I7', 'I8', 'I9'])

print(train['I4'].unique())
print(test['I4'].unique())


temp_y = []
y_test1 = []
for i in train.index:
  if train['I4'][i] <= 2:
    temp_y.append(0)
  elif train['I4'][i] > 2 and train['I4'][i] <= 5:
    temp_y.append(1)
  elif train['I4'][i] > 5 and train['I4'][i] <= 8:
    temp_y.append(2)
  elif train['I4'][i] > 8:
    temp_y.append(3)


for i in test.index:
  if test['I4'][i] <= 2:
    y_test1.append(0)
  elif test['I4'][i] > 2 and test['I4'][i] <= 5:
    y_test1.append(1)
  elif test['I4'][i] > 5 and test['I4'][i] <= 8:
    y_test1.append(2)
  elif test['I4'][i] > 8:
    y_test1.append(3)

y_train = temp_y
y_test = y_test1

# %%
len(y_train)

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=[ '1','2','3']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['1','2','3']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['0','1','2','3']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['1','2','3']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['1','2','3']))

# %% [markdown]
# # ***PREDICT I5***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I6', 'I7','I8', 'I9'])
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I6', 'I7', 'I8', 'I9'])

print(train['I5'].unique())
print(test['I5'].unique())


temp_y = []
y_test1 = []
for i in train.index:
  if train['I5'][i] <= 1:
    temp_y.append(0)
  elif train['I5'][i] > 1 and train['I5'][i] <= 2:
    temp_y.append(1)
  elif train['I5'][i] > 2 and train['I5'][i] <= 3:
    temp_y.append(2)
  elif train['I5'][i] > 3:
    temp_y.append(3)


for i in test.index:
  if test['I5'][i] <= 1:
    y_test1.append(0)
  elif test['I5'][i] > 1 and test['I5'][i] <= 2:
    y_test1.append(1)
  elif test['I5'][i] > 2 and test['I5'][i] <= 3:
    y_test1.append(2)
  elif test['I5'][i] > 3:
    y_test1.append(3)

y_train = temp_y
y_test = y_test1

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier().fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=['1','2','3']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['0','1','2','3']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['1','2','3']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['1','2','3']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['1','2','3']))

# %% [markdown]
# # ***PREDICT I6***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I7','I8', 'I9'])
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I7', 'I8', 'I9'])

print(train['I6'].unique())
print(test['I6'].unique())


temp_y = []
y_test1 = []
for i in train.index:
  if train['I6'][i] <= 1:
    temp_y.append(0)
  elif train['I6'][i] > 1 and train['I6'][i] <= 2:
    temp_y.append(1)
  elif train['I6'][i] > 2 and train['I6'][i] <= 3:
    temp_y.append(2)
  elif train['I6'][i] > 3:
    temp_y.append(3)


for i in test.index:
  if test['I6'][i] <= 1:
    y_test1.append(0)
  elif test['I6'][i] > 1 and test['I6'][i] <= 2:
    y_test1.append(1)
  elif test['I6'][i] > 2 and test['I6'][i] <= 3:
    y_test1.append(2)
  elif test['I6'][i] > 3:
    y_test1.append(3)

y_train = temp_y
y_test = y_test1

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier().fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=['0','1','2','3']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['0','1','2','3']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['0','1','2','3']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['0','1','2','3']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['0','1','2','3']))

# %% [markdown]
# # ***PREDICT I7***

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade','I8', 'I9'])
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I8', 'I9'])

print(train['I7'].unique())
print(test['I7'].unique())


temp_y = []
y_test1 = []
for i in train.index:
  if train['I7'][i] <= 1:
    temp_y.append(0)
  elif train['I7'][i] > 1 and train['I7'][i] <= 2:
    temp_y.append(1)
  elif train['I7'][i] > 2 and train['I7'][i] <= 3:
    temp_y.append(2)
  elif train['I7'][i] > 3:
    temp_y.append(3)


for i in test.index:
  if test['I7'][i] <= 1:
    y_test1.append(0)
  elif test['I7'][i] > 1 and test['I7'][i] <= 2:
    y_test1.append(1)
  elif test['I7'][i] > 2 and test['I7'][i] <= 3:
    y_test1.append(2)
  elif test['I7'][i] > 3:
    y_test1.append(3)

y_train = temp_y
y_test = y_test1

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier().fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=['1','2','3']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['1','2','3']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['1','2','3']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['1','2','3']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['1','2','3']))

# %%
data['Number of Visits'] = data['temp1']
data['Grade'] = data['temp2']
data['I8'] = data['I9']

# %%
data.columns

# %% [markdown]
# # ***PREDICT I8***

# %%
#x_train = train.drop(columns = ['Team', 'Names','Total Number of Visits','temp1', 'temp2','Number of times visited','Total','Grade','I9'])
x_train = train.drop(columns = ['Team', 'Names', 'Total Number of Visits', 'temp1', 'temp2',
         'Category of Commits',
       'Number of times visited',
       'temp2.1', 'I9', 'Grade', 'Total'])
y_train = train['Grade']
x_test = test.drop(columns = ['Team', 'Names', 'Total Number of Visits', 'temp1', 'temp2',
         'Category of Commits',
       'Number of times visited',
       'temp2.1', 'I9', 'Grade', 'Total'])
y_test = test['Grade']

print(y_train.unique())
print(y_test.unique())

# %%
len(train)

# %%
train_sizes = [5,10,20,30,40,50,60,70,80]

# %%
x_train

# %%
trains = pd.DataFrame()
trains['I8'] = train['I8']

# %%
trains['I8']

# %%
temp_y = []
y_test1 = []
for i in trains.index:
  if trains['I8'][i] <= 5:
    temp_y.append(0)
  elif trains['I8'][i] > 5 and trains['I8'][i] <= 10:
    temp_y.append(1)
  elif trains['I8'][i] > 10 and trains['I8'][i] <= 15:
    temp_y.append(2)
  elif trains['I8'][i] > 15:
    temp_y.append(3)


for i in test.index:
  if test['I8'][i] <= 5:
    y_test1.append(0)
  elif test['I8'][i] > 5 and test['I8'][i] <= 10:
    y_test1.append(1)
  elif test['I8'][i] > 10 and test['I8'][i] <= 15:
    y_test1.append(2)
  elif test['I8'][i] > 15:
    y_test1.append(3)

y_train = temp_y
y_test = y_test1

# %%
from sklearn.naive_bayes import GaussianNB

# %%
train_sizes, train_scores, validation_scores = learning_curve(estimator = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50),
                                                              X = x_train ,y = y_train ,
                                                              train_sizes = train_sizes, cv = 5,
                                                              scoring = 'neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
print('Mean training scores\n\n', pd.Series(train_scores_mean, index = train_sizes))
print('\n', '-' * 20) # separator
print('\nMean validation scores\n\n',pd.Series(validation_scores_mean, index = train_sizes))

plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
#plt.title('Logistic Regression Classifier', fontsize = 18, y = 1.03)
plt.legend()
plt.ylim(0,1)

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=['0','1','2','3']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['0','1','2','3']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['0','1','2','3']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['0','1','2','3']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['0','1','2','3']))

# %%
# from sklearn import tree

# %%
# x_train.columns

# %%
# text_representation = tree.export_text(dtree_model)
# print(text_representation)

# %%
# tree1 = []
# for i in y_train.iteritems():
#   a = i
#   tree1.append(str(a[1]))

# %%
# tree1 = []
# for i in y_train.index():
#   #tree1.append(str(y_train[i]))
#   print(y_train[i])

# %%
# fig = plt.figure(figsize=(25,20))
# _ = tree.plot_tree(dtree_model,feature_names=data.columns,class_names=(tree1))

# %%
x_train = train.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I1','I2','I3','I4','I5', 'I6', 'I7','I8', 'I9'])
y_train = train['Grade']
x_test = test.drop(columns = ['Team', 'Names','Number of Commits','Number of times visited','Total','Grade', 'I1','I2','I3','I4','I5', 'I6', 'I7', 'I8', 'I9'])
y_test = test['Grade']

print(y_train.unique())
print(y_test.unique())

# %%
#DESCISION TREE
print('DESCISION TREE')
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
dtree_predictions = dtree_model.predict(x_test)

cm = confusion_matrix(y_test, dtree_predictions)

print('Precision: {:.2f}'.format(precision_score(y_test, dtree_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, dtree_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, dtree_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, dtree_predictions, target_names=['0','1','2','3']))





#SVM
print('SVM')
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train)
svm_predictions = svm_model_linear.predict(x_test)

print("Accuracy =",)

print('Precision: {:.2f}'.format(precision_score(y_test, svm_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, svm_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, svm_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, svm_predictions, target_names=['0','1','2','3']))



#NB
print('NB')
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(x_train, y_train)
gnb_predictions = gnb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, gnb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, gnb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, gnb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, gnb_predictions, target_names=['0','1','2','3']))




#RANDOM FOREST

print('RF')
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(bootstrap = True, max_depth = 10,min_samples_leaf = 2,
                               min_samples_split = 7, n_estimators = 100).fit(x_train, y_train)
rf_predictions = rf.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, rf_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, rf_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, rf_predictions, target_names=['0','1','2','3']))





#XGB
print('XGB')
xgb = XGBClassifier(colsample_bytree = 0.3,max_depth=5,n_estimators = 50).fit(x_train, y_train)
xgb_predictions = xgb.predict(x_test)


print('Precision: {:.2f}'.format(precision_score(y_test, xgb_predictions,average='macro')))
print(' Recall: {:.2f}'.format(recall_score(y_test, xgb_predictions,average='macro')))
print('F1-score: {:.2f}'.format(f1_score(y_test, xgb_predictions,average='macro')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, xgb_predictions, target_names=['0','1','2','3']))
